# %% [markdown]
# # Global Pollution Data Analysis

# %%
#installing libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from scipy import stats

# %% [markdown]
# # About the data set:
# Aggregate data on solid waste management from around the world. This database features the statistics collected through the effort, covering nearly all countries and over 200 cities. The metrics included cover all steps from the waste management value chain, including waste generation, composition, collection, and disposal.
#
# Datasource : Kaggle

# %%
#Loading data to DataFrame
df = pd.read_csv(r"C:\Users\crama\OneDrive\Desktop\Junior Data Analyst course\Portfolio project\GlobalPollution.csv")

# %%
df.head()
# Out:
#   region_id country_name           gdp  \
# 0       LCN        Aruba  35563.312500
# 1       SAS  Afghanistan   2057.062256
# 2       SSF       Angola   8036.690430
# 3       ECS      Albania  13724.058590
# 4       ECS      Andorra  43711.800780
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                    43.2                        4.0
# 1                                    43.2                        4.0
# 2                                    51.8                        6.7
# 3                                    51.4                        4.5
# 4                                    31.2                        8.2
#
#    composition_metal_percent  composition_other_percent  \
# 0                        3.0                      14.00
# 1                        3.0                      14.00
# 2                        4.4                      11.50
# 3                        4.8                      15.21
# 4                        2.6                      11.60
#
#    composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                               13.155                         11.5
# 1                               13.155                         11.5
# 2                               11.900                         13.5
# 3                                9.900                          9.6
# 4                               35.100                         11.3
#
#   other_information_information_system_for_solid_waste_management  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   other_information_ppp_rules_and_regulations  \
# 0                                         Yes
# 1                                         Yes
# 2                                         Yes
# 3                                         Yes
# 4                                         Yes
#
#    population_population_number_of_people  special_waste_e_waste_tons_year  \
# 0                                  103187                          22500.0
# 1                                34656032                          20000.0
# 2                                25096150                          92000.0
# 3                                 2854191                          20000.0
# 4                                   82431                          22500.0
#
#    special_waste_hazardous_waste_tons_year  \
# 0                                212020.50
# 1                                212020.50
# 2                                212020.50
# 3                                  5714.82
# 4                                  1788.00
#
#    total_msw_total_msw_generated_tons_year  waste_treatment_recycling_percent  \
# 0                             8.813202e+04                             11.000
# 1                             5.628525e+06                             13.655
# 2                             4.213644e+06                             13.655
# 3                             1.087447e+06                             13.655
# 4                             4.300000e+04                             13.655
#
#   gdpbins
# 0     Low
# 1     Low
# 2     Low
# 3     Low
# 4     Mid

# %%
#Checking the shape of dataframe
df.shape
# Out:
# (217, 49)

# %%
#Checking the data types of dataframe columns
df.columns
# Out:
# Index(['region_id', 'country_name', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'population_population_number_of_people',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_treatment_recycling_percent', 'gdpbins'],
#       dtype='object')

# %%
#Checking the duplicate values
df.duplicated().value_counts()
# Out:
# False    217
# dtype: int64

# %%
#Checking the data summary
df.describe().T
# Out:
#                                                     count          mean  \
# gdp                                                 217.0  2.254699e+04
# composition_food_organic_waste_percent              176.0  4.173439e+01
# composition_glass_percent                           171.0  4.756173e+00
# composition_metal_percent                           170.0  4.276838e+00
# composition_other_percent                           175.0  1.841801e+01
# composition_paper_cardboard_percent                 176.0  1.527736e+01
# composition_plastic_percent                         175.0  1.168739e+01
# composition_rubber_leather_percent                   53.0  2.671321e+00
# composition_wood_percent                             64.0  4.772031e+00
# composition_yard_garden_green_waste_percent          38.0  1.141994e+01
# population_population_number_of_people              217.0  3.364389e+07
# special_waste_agricultural_waste_tons_year           53.0  9.001569e+07
# special_waste_construction_and_demolition_waste...   74.0  5.777923e+07
# special_waste_e_waste_tons_year                     182.0  2.422950e+05
# special_waste_hazardous_waste_tons_year             118.0  6.934517e+06
# special_waste_industrial_waste_tons_year             40.0  3.150960e+08
# special_waste_medical_waste_tons_year               105.0  3.399483e+06
# total_msw_total_msw_generated_tons_year             215.0  9.638990e+06
# waste_collection_coverage_rural_percent_of_geog...    1.0  1.000000e+02
# waste_collection_coverage_rural_percent_of_hous...    9.0  3.838556e+01
# waste_collection_coverage_rural_percent_of_popu...   23.0  5.099739e+01
# waste_collection_coverage_rural_percent_of_waste      8.0  3.175000e+01
# waste_collection_coverage_total_percent_of_geog...    1.0  1.000000e+02
# waste_collection_coverage_total_percent_of_hous...   12.0  6.002583e+01
# waste_collection_coverage_total_percent_of_popu...   92.0  7.349011e+01
# waste_collection_coverage_total_percent_of_waste     50.0  8.502063e+01
# waste_collection_coverage_urban_percent_of_geog...    1.0  1.000000e+02
# waste_collection_coverage_urban_percent_of_hous...    9.0  7.905111e+01
# waste_collection_coverage_urban_percent_of_popu...   40.0  8.122275e+01
# waste_collection_coverage_urban_percent_of_waste      9.0  6.946556e+01
# waste_treatment_anaerobic_digestion_percent           2.0  2.000000e-01
# waste_treatment_compost_percent                      68.0  8.138042e+00
# waste_treatment_controlled_landfill_percent          43.0  4.221310e+01
# waste_treatment_incineration_percent                 48.0  2.843439e+01
# waste_treatment_landfill_unspecified_percent         63.0  4.784270e+01
# waste_treatment_open_dump_percent                    68.0  5.479140e+01
# waste_treatment_other_percent                        25.0  1.323620e+01
# waste_treatment_recycling_percent                   124.0  1.737157e+01
# waste_treatment_sanitary_landfill_landfill_gas_...   28.0  4.435627e+01
# waste_treatment_unaccounted_for_percent              94.0  3.282213e+01
# waste_treatment_waterways_marine_percent              4.0  3.802500e+01
#
#                                                              std  \
# gdp                                                 2.265798e+04
# composition_food_organic_waste_percent              1.789823e+01
# composition_glass_percent                           3.399614e+00
# composition_metal_percent                           3.522976e+00
# composition_other_percent                           1.601518e+01
# composition_paper_cardboard_percent                 9.478098e+00
# composition_plastic_percent                         5.585085e+00
# composition_rubber_leather_percent                  2.769187e+00
# composition_wood_percent                            6.905955e+00
# composition_yard_garden_green_waste_percent         1.265226e+01
# population_population_number_of_people              1.365838e+08
# special_waste_agricultural_waste_tons_year          5.484435e+08
# special_waste_construction_and_demolition_waste...  1.885311e+08
# special_waste_e_waste_tons_year                     7.255031e+05
# special_waste_hazardous_waste_tons_year             4.248432e+07
# special_waste_industrial_waste_tons_year            1.299883e+09
# special_waste_medical_waste_tons_year               2.850073e+07
# total_msw_total_msw_generated_tons_year             3.600216e+07
# waste_collection_coverage_rural_percent_of_geog...           NaN
# waste_collection_coverage_rural_percent_of_hous...  3.619015e+01
# waste_collection_coverage_rural_percent_of_popu...  4.031665e+01
# waste_collection_coverage_rural_percent_of_waste    1.312304e+01
# waste_collection_coverage_total_percent_of_geog...           NaN
# waste_collection_coverage_total_percent_of_hous...  3.470430e+01
# waste_collection_coverage_total_percent_of_popu...  2.780951e+01
# waste_collection_coverage_total_percent_of_waste    1.957668e+01
# waste_collection_coverage_urban_percent_of_geog...           NaN
# waste_collection_coverage_urban_percent_of_hous...  2.894396e+01
# waste_collection_coverage_urban_percent_of_popu...  2.438459e+01
# waste_collection_coverage_urban_percent_of_waste    1.582524e+01
# waste_treatment_anaerobic_digestion_percent         1.414214e-01
# waste_treatment_compost_percent                     7.594840e+00
# waste_treatment_controlled_landfill_percent         3.413660e+01
# waste_treatment_incineration_percent                2.354302e+01
# waste_treatment_landfill_unspecified_percent        2.985438e+01
# waste_treatment_open_dump_percent                   3.086309e+01
# waste_treatment_other_percent                       1.403924e+01
# waste_treatment_recycling_percent                   1.522763e+01
# waste_treatment_sanitary_landfill_landfill_gas_...  2.953304e+01
# waste_treatment_unaccounted_for_percent             3.323732e+01
# waste_treatment_waterways_marine_percent            4.004334e+01
#
#                                                              min  \
# gdp                                                   822.610474
# composition_food_organic_waste_percent                  3.100000
# composition_glass_percent                               0.000000
# composition_metal_percent                               0.100000
# composition_other_percent                               0.800000
# composition_paper_cardboard_percent                     2.000000
# composition_plastic_percent                             1.000000
# composition_rubber_leather_percent                      0.000000
# composition_wood_percent                                0.400000
# composition_yard_garden_green_waste_percent             0.930000
# population_population_number_of_people              11097.000000
# special_waste_agricultural_waste_tons_year            132.534200
# special_waste_construction_and_demolition_waste...   1000.000000
# special_waste_e_waste_tons_year                        10.000000
# special_waste_hazardous_waste_tons_year                 4.920000
# special_waste_industrial_waste_tons_year              766.500000
# special_waste_medical_waste_tons_year                   5.720000
# total_msw_total_msw_generated_tons_year              3989.486500
# waste_collection_coverage_rural_percent_of_geog...    100.000000
# waste_collection_coverage_rural_percent_of_hous...      0.400000
# waste_collection_coverage_rural_percent_of_popu...      0.040000
# waste_collection_coverage_rural_percent_of_waste        6.000000
# waste_collection_coverage_total_percent_of_geog...    100.000000
# waste_collection_coverage_total_percent_of_hous...      4.220000
# waste_collection_coverage_total_percent_of_popu...      8.000000
# waste_collection_coverage_total_percent_of_waste       34.520000
# waste_collection_coverage_urban_percent_of_geog...    100.000000
# waste_collection_coverage_urban_percent_of_hous...     11.760000
# waste_collection_coverage_urban_percent_of_popu...     23.800000
# waste_collection_coverage_urban_percent_of_waste       37.000000
# waste_treatment_anaerobic_digestion_percent             0.100000
# waste_treatment_compost_percent                         0.080000
# waste_treatment_controlled_landfill_percent             0.010000
# waste_treatment_incineration_percent                    0.140000
# waste_treatment_landfill_unspecified_percent            0.210000
# waste_treatment_open_dump_percent                       4.000000
# waste_treatment_other_percent                           0.025000
# waste_treatment_recycling_percent                       0.000970
# waste_treatment_sanitary_landfill_landfill_gas_...      0.100000
# waste_treatment_unaccounted_for_percent                 0.010000
# waste_treatment_waterways_marine_percent                0.100000
#
#                                                               25%  \
# gdp                                                   4783.635742
# composition_food_organic_waste_percent                  29.225000
# composition_glass_percent                                2.805000
# composition_metal_percent                                2.000000
# composition_other_percent                                9.000000
# composition_paper_cardboard_percent                      8.625000
# composition_plastic_percent                              7.950000
# composition_rubber_leather_percent                       0.900000
# composition_wood_percent                                 1.000000
# composition_yard_garden_green_waste_percent              2.542500
# population_population_number_of_people              746221.000000
# special_waste_agricultural_waste_tons_year          199453.000000
# special_waste_construction_and_demolition_waste...  687402.500000
# special_waste_e_waste_tons_year                       5750.000000
# special_waste_hazardous_waste_tons_year              16598.750000
# special_waste_industrial_waste_tons_year             54312.500000
# special_waste_medical_waste_tons_year                  834.000000
# total_msw_total_msw_generated_tons_year             213879.468000
# waste_collection_coverage_rural_percent_of_geog...     100.000000
# waste_collection_coverage_rural_percent_of_hous...       7.000000
# waste_collection_coverage_rural_percent_of_popu...      12.500000
# waste_collection_coverage_rural_percent_of_waste        27.250000
# waste_collection_coverage_total_percent_of_geog...     100.000000
# waste_collection_coverage_total_percent_of_hous...      38.500000
# waste_collection_coverage_total_percent_of_popu...      57.200000
# waste_collection_coverage_total_percent_of_waste        78.390377
# waste_collection_coverage_urban_percent_of_geog...     100.000000
# waste_collection_coverage_urban_percent_of_hous...      67.000000
# waste_collection_coverage_urban_percent_of_popu...      64.597500
# waste_collection_coverage_urban_percent_of_waste        65.000000
# waste_treatment_anaerobic_digestion_percent              0.150000
# waste_treatment_compost_percent                          1.472500
# waste_treatment_controlled_landfill_percent             11.000000
# waste_treatment_incineration_percent                    10.475000
# waste_treatment_landfill_unspecified_percent            22.624000
# waste_treatment_open_dump_percent                       23.400000
# waste_treatment_other_percent                            2.000000
# waste_treatment_recycling_percent                        5.000000
# waste_treatment_sanitary_landfill_landfill_gas_...      18.325000
# waste_treatment_unaccounted_for_percent                  3.057500
# waste_treatment_waterways_marine_percent                 6.025000
#
#                                                              50%  \
# gdp                                                 1.320771e+04
# composition_food_organic_waste_percent              4.320000e+01
# composition_glass_percent                           4.000000e+00
# composition_metal_percent                           3.000000e+00
# composition_other_percent                           1.400000e+01
# composition_paper_cardboard_percent                 1.315500e+01
# composition_plastic_percent                         1.150000e+01
# composition_rubber_leather_percent                  1.500000e+00
# composition_wood_percent                            2.440000e+00
# composition_yard_garden_green_waste_percent         6.318844e+00
# population_population_number_of_people              5.737723e+06
# special_waste_agricultural_waste_tons_year          1.063964e+06
# special_waste_construction_and_demolition_waste...  3.820575e+06
# special_waste_e_waste_tons_year                     2.250000e+04
# special_waste_hazardous_waste_tons_year             2.120205e+05
# special_waste_industrial_waste_tons_year            5.203958e+05
# special_waste_medical_waste_tons_year               1.340827e+04
# total_msw_total_msw_generated_tons_year             1.787400e+06
# waste_collection_coverage_rural_percent_of_geog...  1.000000e+02
# waste_collection_coverage_rural_percent_of_hous...  2.800000e+01
# waste_collection_coverage_rural_percent_of_popu...  4.250000e+01
# waste_collection_coverage_rural_percent_of_waste    3.250000e+01
# waste_collection_coverage_total_percent_of_geog...  1.000000e+02
# waste_collection_coverage_total_percent_of_hous...  6.399500e+01
# waste_collection_coverage_total_percent_of_popu...  7.915000e+01
# waste_collection_coverage_total_percent_of_waste    9.409000e+01
# waste_collection_coverage_urban_percent_of_geog...  1.000000e+02
# waste_collection_coverage_urban_percent_of_hous...  9.300000e+01
# waste_collection_coverage_urban_percent_of_popu...  9.241000e+01
# waste_collection_coverage_urban_percent_of_waste    7.000000e+01
# waste_treatment_anaerobic_digestion_percent         2.000000e-01
# waste_treatment_compost_percent                     5.740000e+00
# waste_treatment_controlled_landfill_percent         3.300000e+01
# waste_treatment_incineration_percent                2.284000e+01
# waste_treatment_landfill_unspecified_percent        5.200000e+01
# waste_treatment_open_dump_percent                   5.769500e+01
# waste_treatment_other_percent                       9.140000e+00
# waste_treatment_recycling_percent                   1.365500e+01
# waste_treatment_sanitary_landfill_landfill_gas_...  3.935000e+01
# waste_treatment_unaccounted_for_percent             1.906208e+01
# waste_treatment_waterways_marine_percent            3.550000e+01
#
#                                                              75%           max
# gdp                                                 3.556331e+04  1.173356e+05
# composition_food_organic_waste_percent              5.455000e+01  8.760000e+01
# composition_glass_percent                           5.900000e+00  2.140000e+01
# composition_metal_percent                           5.000000e+00  1.938000e+01
# composition_other_percent                           2.235135e+01  9.270000e+01
# composition_paper_cardboard_percent                 2.000000e+01  5.870000e+01
# composition_plastic_percent                         1.455500e+01  3.200000e+01
# composition_rubber_leather_percent                  4.200000e+00  1.260000e+01
# composition_wood_percent                            5.575000e+00  3.820000e+01
# composition_yard_garden_green_waste_percent         1.516750e+01  6.500000e+01
# population_population_number_of_people              2.120300e+07  1.400050e+09
# special_waste_agricultural_waste_tons_year          1.036579e+07  4.000000e+09
# special_waste_construction_and_demolition_waste...  4.447460e+07  1.500000e+09
# special_waste_e_waste_tons_year                     1.492500e+05  7.211000e+06
# special_waste_hazardous_waste_tons_year             1.524000e+06  4.480000e+08
# special_waste_industrial_waste_tons_year            6.900000e+06  7.600000e+09
# special_waste_medical_waste_tons_year               4.500000e+05  2.920000e+08
# total_msw_total_msw_generated_tons_year             5.282711e+06  3.950814e+08
# waste_collection_coverage_rural_percent_of_geog...  1.000000e+02  1.000000e+02
# waste_collection_coverage_rural_percent_of_hous...  6.340000e+01  9.540000e+01
# waste_collection_coverage_rural_percent_of_popu...  9.450000e+01  1.000000e+02
# waste_collection_coverage_rural_percent_of_waste    4.000000e+01  5.000000e+01
# waste_collection_coverage_total_percent_of_geog...  1.000000e+02  1.000000e+02
# waste_collection_coverage_total_percent_of_hous...  9.035000e+01  9.830000e+01
# waste_collection_coverage_total_percent_of_popu...  9.900000e+01  1.000000e+02
# waste_collection_coverage_total_percent_of_waste    9.859250e+01  1.000000e+02
# waste_collection_coverage_urban_percent_of_geog...  1.000000e+02  1.000000e+02
# waste_collection_coverage_urban_percent_of_hous...  9.720000e+01  9.930000e+01
# waste_collection_coverage_urban_percent_of_popu...  1.000000e+02  1.000000e+02
# waste_collection_coverage_urban_percent_of_waste    7.819000e+01  9.500000e+01
# waste_treatment_anaerobic_digestion_percent         2.500000e-01  3.000000e-01
# waste_treatment_compost_percent                     1.515750e+01  3.124000e+01
# waste_treatment_controlled_landfill_percent         6.921500e+01  1.000000e+02
# waste_treatment_incineration_percent                4.709225e+01  8.500000e+01
# waste_treatment_landfill_unspecified_percent        7.075000e+01  1.000000e+02
# waste_treatment_open_dump_percent                   8.122500e+01  1.000000e+02
# waste_treatment_other_percent                       1.890000e+01  6.000000e+01
# waste_treatment_recycling_percent                   2.599500e+01  6.700000e+01
# waste_treatment_sanitary_landfill_landfill_gas_...  6.812500e+01  9.100000e+01
# waste_treatment_unaccounted_for_percent             6.009750e+01  9.900000e+01
# waste_treatment_waterways_marine_percent            6.750000e+01  8.100000e+01

# %%
#Checking null values
df.isnull().sum()
# Out:
# region_id                                                                                  0
# country_name                                                                               1
# gdp                                                                                        0
# composition_food_organic_waste_percent                                                    41
# composition_glass_percent                                                                 46
# composition_metal_percent                                                                 47
# composition_other_percent                                                                 42
# composition_paper_cardboard_percent                                                       41
# composition_plastic_percent                                                               42
# composition_rubber_leather_percent                                                       164
# composition_wood_percent                                                                 153
# composition_yard_garden_green_waste_percent                                              179
# other_information_information_system_for_solid_waste_management                          105
# other_information_national_agency_to_enforce_solid_waste_laws_and_regulations             53
# other_information_national_law_governing_solid_waste_management_in_the_country            23
# other_information_ppp_rules_and_regulations                                               55
# other_information_summary_of_key_solid_waste_information_made_available_to_the_public    144
# population_population_number_of_people                                                     0
# special_waste_agricultural_waste_tons_year                                               164
# special_waste_construction_and_demolition_waste_tons_year                                143
# special_waste_e_waste_tons_year                                                           35
# special_waste_hazardous_waste_tons_year                                                   99
# special_waste_industrial_waste_tons_year                                                 177
# special_waste_medical_waste_tons_year                                                    112
# total_msw_total_msw_generated_tons_year                                                    2
# waste_collection_coverage_rural_percent_of_geographic_area                               216
# waste_collection_coverage_rural_percent_of_households                                    208
# waste_collection_coverage_rural_percent_of_population                                    194
# waste_collection_coverage_rural_percent_of_waste                                         209
# waste_collection_coverage_total_percent_of_geographic_area                               216
# waste_collection_coverage_total_percent_of_households                                    205
# waste_collection_coverage_total_percent_of_population                                    125
# waste_collection_coverage_total_percent_of_waste                                         167
# waste_collection_coverage_urban_percent_of_geographic_area                               216
# waste_collection_coverage_urban_percent_of_households                                    208
# waste_collection_coverage_urban_percent_of_population                                    177
# waste_collection_coverage_urban_percent_of_waste                                         208
# waste_treatment_anaerobic_digestion_percent                                              215
# waste_treatment_compost_percent                                                          149
# waste_treatment_controlled_landfill_percent                                              174
# waste_treatment_incineration_percent                                                     169
# waste_treatment_landfill_unspecified_percent                                             154
# waste_treatment_open_dump_percent                                                        149
# waste_treatment_other_percent                                                            192
# waste_treatment_recycling_percent                                                         93
# waste_treatment_sanitary_landfill_landfill_gas_system_percent                            189
# waste_treatment_unaccounted_for_percent                                                  123
# waste_treatment_waterways_marine_percent                                                 213
# where_where_is_this_data_measured                                                        160
# dtype: int64

# %% [markdown]
# # EDA
# Analyzing the data set for understanding the data and getting insights

# %%
#Null values handling - removing columns which is having more than 50% null values
for i in df.columns:

    if df[i].isna().sum() > (len(df) / 2):
        del df[i]

df
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ..                                      ...                        ...
# 212                               42.000000                   6.000000
# 213                               65.000000                   1.000000
# 214                               16.381655                   5.200216
# 215                                     NaN                        NaN
# 216                               36.000000                   5.000000
#
#      composition_metal_percent  composition_other_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                     4.400000                  11.500000
# 3                     4.800000                  15.210000
# 4                     2.600000                  11.600000
# ..                         ...                        ...
# 212                   6.000000                  20.000000
# 213                   6.000000                   6.000000
# 214                  16.910461                  45.020646
# 215                        NaN                        NaN
# 216                   6.000000                   3.000000
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                              11.900000                    13.500000
# 3                               9.900000                     9.600000
# 4                              35.100000                    11.300000
# ..                                   ...                          ...
# 212                             8.000000                    11.000000
# 213                             7.000000                    10.000000
# 214                             9.396918                     7.090104
# 215                                  NaN                          NaN
# 216                            27.000000                    23.000000
#
#     other_information_information_system_for_solid_waste_management  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 212                                                Yes
# 213                                                 No
# 214                                                Yes
# 215                                                NaN
# 216                                                NaN
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  NaN
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                NaN
# 216                                                NaN
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                Yes
# 216                                                Yes
#
#     other_information_ppp_rules_and_regulations  \
# 0                                           Yes
# 1                                           Yes
# 2                                           Yes
# 3                                           Yes
# 4                                           Yes
# ..                                          ...
# 212                                         Yes
# 213                                          No
# 214                                         NaN
# 215                                         NaN
# 216                                         NaN
#
#      population_population_number_of_people  special_waste_e_waste_tons_year  \
# 0                                    103187                              NaN
# 1                                  34656032                          20000.0
# 2                                  25096150                          92000.0
# 3                                   2854191                          20000.0
# 4                                     82431                              NaN
# ..                                      ...                              ...
# 212                                 1801800                             23.0
# 213                                27584212                          42000.0
# 214                                51729344                         321000.0
# 215                                14264756                          15000.0
# 216                                12500525                          13000.0
#
#      special_waste_hazardous_waste_tons_year  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                    5714.82
# 4                                    1788.00
# ..                                       ...
# 212                                   495.00
# 213                                 21000.00
# 214                               1319096.00
# 215                                 80000.00
# 216                                 37346.00
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 212                             3.190000e+05
# 213                             4.836820e+06
# 214                             1.845723e+07
# 215                             2.608268e+06
# 216                             1.449752e+06
#
#      waste_treatment_recycling_percent
# 0                                 11.0
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 212                                NaN
# 213                                8.0
# 214                               28.0
# 215                                NaN
# 216                               16.0
#
# [217 rows x 18 columns]

# %%
#replacing null values with median and mode values

def mode_imput(i):
    df[i] = df[i].fillna(df[i].mode()[0])
    return df[i]

for i in df.select_dtypes(include = "object").columns:
    mode_imput(i)

def median_imput(i):
    df[i] = df[i].fillna(df[i].median())
    return df[i]

for i in df.select_dtypes(include = "number").columns:
    median_imput(i)

# %%
df.isnull().sum()
# Out:
# region_id                                                                         0
# country_name                                                                      0
# gdp                                                                               0
# composition_food_organic_waste_percent                                            0
# composition_glass_percent                                                         0
# composition_metal_percent                                                         0
# composition_other_percent                                                         0
# composition_paper_cardboard_percent                                               0
# composition_plastic_percent                                                       0
# other_information_information_system_for_solid_waste_management                   0
# other_information_national_agency_to_enforce_solid_waste_laws_and_regulations     0
# other_information_national_law_governing_solid_waste_management_in_the_country    0
# other_information_ppp_rules_and_regulations                                       0
# population_population_number_of_people                                            0
# special_waste_e_waste_tons_year                                                   0
# special_waste_hazardous_waste_tons_year                                           0
# total_msw_total_msw_generated_tons_year                                           0
# waste_treatment_recycling_percent                                                 0
# dtype: int64

# %% [markdown]
# ## Finding correlations

# %%
#Correlation in the dataframe
df.corr()
# Out:
#                                               gdp  \
# gdp                                      1.000000
# composition_food_organic_waste_percent  -0.414989
# composition_glass_percent                0.199968
# composition_metal_percent                0.200397
# composition_other_percent               -0.025269
# composition_paper_cardboard_percent      0.546371
# composition_plastic_percent              0.058344
# population_population_number_of_people  -0.060911
# special_waste_e_waste_tons_year          0.131925
# special_waste_hazardous_waste_tons_year -0.013853
# total_msw_total_msw_generated_tons_year  0.041157
# waste_treatment_recycling_percent        0.469342
#
#                                          composition_food_organic_waste_percent  \
# gdp                                                                   -0.414989
# composition_food_organic_waste_percent                                 1.000000
# composition_glass_percent                                             -0.311934
# composition_metal_percent                                             -0.290348
# composition_other_percent                                             -0.423783
# composition_paper_cardboard_percent                                   -0.479389
# composition_plastic_percent                                           -0.197066
# population_population_number_of_people                                 0.092317
# special_waste_e_waste_tons_year                                       -0.028325
# special_waste_hazardous_waste_tons_year                               -0.038783
# total_msw_total_msw_generated_tons_year                                0.022499
# waste_treatment_recycling_percent                                     -0.284057
#
#                                          composition_glass_percent  \
# gdp                                                       0.199968
# composition_food_organic_waste_percent                   -0.311934
# composition_glass_percent                                 1.000000
# composition_metal_percent                                 0.162807
# composition_other_percent                                -0.107657
# composition_paper_cardboard_percent                       0.291117
# composition_plastic_percent                               0.122060
# population_population_number_of_people                   -0.067013
# special_waste_e_waste_tons_year                           0.043112
# special_waste_hazardous_waste_tons_year                   0.078329
# total_msw_total_msw_generated_tons_year                  -0.027271
# waste_treatment_recycling_percent                         0.038741
#
#                                          composition_metal_percent  \
# gdp                                                       0.200397
# composition_food_organic_waste_percent                   -0.290348
# composition_glass_percent                                 0.162807
# composition_metal_percent                                 1.000000
# composition_other_percent                                -0.098244
# composition_paper_cardboard_percent                       0.172515
# composition_plastic_percent                               0.138189
# population_population_number_of_people                   -0.085343
# special_waste_e_waste_tons_year                          -0.040100
# special_waste_hazardous_waste_tons_year                  -0.014854
# total_msw_total_msw_generated_tons_year                  -0.029535
# waste_treatment_recycling_percent                         0.272423
#
#                                          composition_other_percent  \
# gdp                                                      -0.025269
# composition_food_organic_waste_percent                   -0.423783
# composition_glass_percent                                -0.107657
# composition_metal_percent                                -0.098244
# composition_other_percent                                 1.000000
# composition_paper_cardboard_percent                      -0.238300
# composition_plastic_percent                              -0.166241
# population_population_number_of_people                   -0.054808
# special_waste_e_waste_tons_year                          -0.030512
# special_waste_hazardous_waste_tons_year                   0.014528
# total_msw_total_msw_generated_tons_year                  -0.071095
# waste_treatment_recycling_percent                         0.024593
#
#                                          composition_paper_cardboard_percent  \
# gdp                                                                 0.546371
# composition_food_organic_waste_percent                             -0.479389
# composition_glass_percent                                           0.291117
# composition_metal_percent                                           0.172515
# composition_other_percent                                          -0.238300
# composition_paper_cardboard_percent                                 1.000000
# composition_plastic_percent                                         0.182368
# population_population_number_of_people                             -0.039760
# special_waste_e_waste_tons_year                                     0.096645
# special_waste_hazardous_waste_tons_year                             0.095572
# total_msw_total_msw_generated_tons_year                             0.036718
# waste_treatment_recycling_percent                                   0.253963
#
#                                          composition_plastic_percent  \
# gdp                                                         0.058344
# composition_food_organic_waste_percent                     -0.197066
# composition_glass_percent                                   0.122060
# composition_metal_percent                                   0.138189
# composition_other_percent                                  -0.166241
# composition_paper_cardboard_percent                         0.182368
# composition_plastic_percent                                 1.000000
# population_population_number_of_people                     -0.038023
# special_waste_e_waste_tons_year                             0.011820
# special_waste_hazardous_waste_tons_year                    -0.051137
# total_msw_total_msw_generated_tons_year                    -0.016381
# waste_treatment_recycling_percent                          -0.018287
#
#                                          population_population_number_of_people  \
# gdp                                                                   -0.060911
# composition_food_organic_waste_percent                                 0.092317
# composition_glass_percent                                             -0.067013
# composition_metal_percent                                             -0.085343
# composition_other_percent                                             -0.054808
# composition_paper_cardboard_percent                                   -0.039760
# composition_plastic_percent                                           -0.038023
# population_population_number_of_people                                 1.000000
# special_waste_e_waste_tons_year                                        0.715410
# special_waste_hazardous_waste_tons_year                                0.096230
# total_msw_total_msw_generated_tons_year                                0.879682
# waste_treatment_recycling_percent                                     -0.060076
#
#                                          special_waste_e_waste_tons_year  \
# gdp                                                             0.131925
# composition_food_organic_waste_percent                         -0.028325
# composition_glass_percent                                       0.043112
# composition_metal_percent                                      -0.040100
# composition_other_percent                                      -0.030512
# composition_paper_cardboard_percent                             0.096645
# composition_plastic_percent                                     0.011820
# population_population_number_of_people                          0.715410
# special_waste_e_waste_tons_year                                 1.000000
# special_waste_hazardous_waste_tons_year                         0.137002
# total_msw_total_msw_generated_tons_year                         0.841274
# waste_treatment_recycling_percent                               0.109627
#
#                                          special_waste_hazardous_waste_tons_year  \
# gdp                                                                    -0.013853
# composition_food_organic_waste_percent                                 -0.038783
# composition_glass_percent                                               0.078329
# composition_metal_percent                                              -0.014854
# composition_other_percent                                               0.014528
# composition_paper_cardboard_percent                                     0.095572
# composition_plastic_percent                                            -0.051137
# population_population_number_of_people                                  0.096230
# special_waste_e_waste_tons_year                                         0.137002
# special_waste_hazardous_waste_tons_year                                 1.000000
# total_msw_total_msw_generated_tons_year                                 0.134788
# waste_treatment_recycling_percent                                      -0.069083
#
#                                          total_msw_total_msw_generated_tons_year  \
# gdp                                                                     0.041157
# composition_food_organic_waste_percent                                  0.022499
# composition_glass_percent                                              -0.027271
# composition_metal_percent                                              -0.029535
# composition_other_percent                                              -0.071095
# composition_paper_cardboard_percent                                     0.036718
# composition_plastic_percent                                            -0.016381
# population_population_number_of_people                                  0.879682
# special_waste_e_waste_tons_year                                         0.841274
# special_waste_hazardous_waste_tons_year                                 0.134788
# total_msw_total_msw_generated_tons_year                                 1.000000
# waste_treatment_recycling_percent                                       0.017983
#
#                                          waste_treatment_recycling_percent
# gdp                                                               0.469342
# composition_food_organic_waste_percent                           -0.284057
# composition_glass_percent                                         0.038741
# composition_metal_percent                                         0.272423
# composition_other_percent                                         0.024593
# composition_paper_cardboard_percent                               0.253963
# composition_plastic_percent                                      -0.018287
# population_population_number_of_people                           -0.060076
# special_waste_e_waste_tons_year                                   0.109627
# special_waste_hazardous_waste_tons_year                          -0.069083
# total_msw_total_msw_generated_tons_year                           0.017983
# waste_treatment_recycling_percent                                 1.000000

# %%
#replacing gdp with bins
df['gdpbins'] = pd.cut(df.gdp,bins=3,labels=['Low','Mid','High'])

# %%
#Checking the dataframe with gdp bins
df
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                 43.200000                   4.000000
# 1                                 43.200000                   4.000000
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ..                                      ...                        ...
# 212                               42.000000                   6.000000
# 213                               65.000000                   1.000000
# 214                               16.381655                   5.200216
# 215                               43.200000                   4.000000
# 216                               36.000000                   5.000000
#
#      composition_metal_percent  composition_other_percent  \
# 0                     3.000000                  14.000000
# 1                     3.000000                  14.000000
# 2                     4.400000                  11.500000
# 3                     4.800000                  15.210000
# 4                     2.600000                  11.600000
# ..                         ...                        ...
# 212                   6.000000                  20.000000
# 213                   6.000000                   6.000000
# 214                  16.910461                  45.020646
# 215                   3.000000                  14.000000
# 216                   6.000000                   3.000000
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                              13.155000                    11.500000
# 1                              13.155000                    11.500000
# 2                              11.900000                    13.500000
# 3                               9.900000                     9.600000
# 4                              35.100000                    11.300000
# ..                                   ...                          ...
# 212                             8.000000                    11.000000
# 213                             7.000000                    10.000000
# 214                             9.396918                     7.090104
# 215                            13.155000                    11.500000
# 216                            27.000000                    23.000000
#
#     other_information_information_system_for_solid_waste_management  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                 No
# 214                                                Yes
# 215                                                Yes
# 216                                                Yes
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                Yes
# 216                                                Yes
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                Yes
# 216                                                Yes
#
#     other_information_ppp_rules_and_regulations  \
# 0                                           Yes
# 1                                           Yes
# 2                                           Yes
# 3                                           Yes
# 4                                           Yes
# ..                                          ...
# 212                                         Yes
# 213                                          No
# 214                                         Yes
# 215                                         Yes
# 216                                         Yes
#
#      population_population_number_of_people  special_waste_e_waste_tons_year  \
# 0                                    103187                          22500.0
# 1                                  34656032                          20000.0
# 2                                  25096150                          92000.0
# 3                                   2854191                          20000.0
# 4                                     82431                          22500.0
# ..                                      ...                              ...
# 212                                 1801800                             23.0
# 213                                27584212                          42000.0
# 214                                51729344                         321000.0
# 215                                14264756                          15000.0
# 216                                12500525                          13000.0
#
#      special_waste_hazardous_waste_tons_year  \
# 0                                  212020.50
# 1                                  212020.50
# 2                                  212020.50
# 3                                    5714.82
# 4                                    1788.00
# ..                                       ...
# 212                                   495.00
# 213                                 21000.00
# 214                               1319096.00
# 215                                 80000.00
# 216                                 37346.00
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 212                             3.190000e+05
# 213                             4.836820e+06
# 214                             1.845723e+07
# 215                             2.608268e+06
# 216                             1.449752e+06
#
#      waste_treatment_recycling_percent gdpbins
# 0                               11.000     Low
# 1                               13.655     Low
# 2                               13.655     Low
# 3                               13.655     Low
# 4                               13.655     Mid
# ..                                 ...     ...
# 212                             13.655     Low
# 213                              8.000     Low
# 214                             28.000     Low
# 215                             13.655     Low
# 216                             16.000     Low
#
# [217 rows x 19 columns]

# %%
#Plotting heatmap using seaborn lib to visualize the correlation
plt.figure(figsize = (16,9))
sns.heatmap(df.corr(), annot = True, linewidths = 1)
plt.show()

# %%
#Relation between gdp and food organic waste percent - Negative correlation

sns.lmplot(x='gdp',y='composition_food_organic_waste_percent',data=df)

plt.show()

# %% [markdown]
# There is a negative correlation seen with the gdp and the food waste percent. It says that the developed countries are good at reducing food waste and the countries with low gdp are producing high food waste

# %%
#Relation between population vs E-waste tons generated(Red) and MSW(Green) generated - Positive correlation

sns.scatterplot(x='population_population_number_of_people',
                y='total_msw_total_msw_generated_tons_year',
                data=df,
                markers='o',
                hue='gdpbins')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
sns.scatterplot(x='population_population_number_of_people',
                y='special_waste_e_waste_tons_year',
                data=df,
                hue='gdpbins')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# There is a positive correlation seen with the population vs the E-waste and the Municipal supply waste generated of the country. It says that the when the population is growing there is an increase in E-waste and MSW , which is to be alerted and to be treated. Let's check the waste treatment of the countries.

# %% [markdown]
# # Pairplot is used to identify the correlation between various numeric variables.
# Here seaborn pairplot is used.

# %%
#Using seaborn pairplot to find the correlation of numeric variables in the dataframe
#plt.figure(figsize = (30,40))
sns.pairplot(data=df,hue='gdpbins')
plt.show()

# %% [markdown]
# ### Findings :
# ### Positive correlations:
# gdp vs waste treatment recycling percentage,
# gdp vs composition paper carboard waste,
# composition paper carboard waste vs composition plastic waste,
# gdp vs composition glass percent,
# gdp vs composition metal percent,
# composition plastic waste vs composition glass percent,
#
# ### Negative correlations :
# gdp vs composition food organic waste,
# composition paper carboard waste vs composition other waste,
# composition plastic waste vs composition food organic waste

# %%
#Finding the distribution of numeric columns data in the dataframe 
plt.figure(figsize = (25,16))

for i,j in enumerate(df.select_dtypes(include = "number").columns):
    plt.subplot(3,4,i+1)
    sns.distplot(df[j], kde_kws = {"color":"red", "lw":2})
plt.show()

# %%
#Boxplot to identify the outliers

plt.figure(figsize = (25,16))

for i,j in enumerate(df.select_dtypes(include = "number").columns):
    plt.subplot(3,4,i+1)
    sns.boxplot(df[j])
    plt.xlabel("{}".format(j))
plt.show()

# %%
#Finding the normal distribution of the data (numeric) in the dataframe
plt.figure(figsize = (25,16))

for i,j in enumerate(df.select_dtypes(include = "number").columns):
    plt.subplot(3,4,i+1)
    stats.probplot(df[j], dist = "norm", plot = plt)
    plt.ylabel("{}".format(j))

plt.show()

# %% [markdown]
# ## Note:
# Outliers are not removed in this data set because it is related to pollution and there might be possibility of such high values and so those values are considered for analysis. Most outliers are related to China and India, It is evident that these countries are the most popuplated country. Hence it cannot be considered as Outlier.

# %% [markdown]
# # Questions:
# 1. Which countries producing the most composition_food_organic_waste_percent
# 2. Which countries producing the most composition_glass_percent
# 3. Which countries producing the most composition_metal_percent
# 4. Which countries producing the most composition_other_percent
# 5. Which countries producing the most composition_paper_cardboard_percent
# 6. Which countries producing the most composition_plastic_percent',
# 7. Which countries having the most population_population_number_of_people',
# 8. Which countries producing the most special_waste_e_waste_tons_year',
# 9. Which countries producing the most special_waste_hazardous_waste_tons_year',
# 10. Which countries producing the most total_msw_total_msw_generated_tons_year',
# 11. Which countries having the most waste_treatment_recycling_percent

# %%
df_max=pd.DataFrame()
result1=[]
result2=[]
result3=[]
for i in enumerate(df[['composition_food_organic_waste_percent',
                        'composition_glass_percent',
                        'composition_metal_percent',
                        'composition_other_percent',
                        'composition_paper_cardboard_percent',
                        'composition_plastic_percent',
                        'population_population_number_of_people',
                        'special_waste_e_waste_tons_year',
                        'special_waste_hazardous_waste_tons_year',
                        'total_msw_total_msw_generated_tons_year',
                        'waste_treatment_recycling_percent']]):
    result1.append(i[1])
    result2.append(df[df[i[1]]==max(df[i[1]])]['country_name'].to_string(index=False))
    result3.append(df[df[i[1]]==max(df[i[1]])]['waste_treatment_recycling_percent'].to_string(index=False))
df_max['Category']=result1
df_max['Country']= result2
df_max['Waste recycling percent']= result3
display(df_max)
# Out:
#                                    Category                  Country  \
# 0    composition_food_organic_waste_percent                 Ethiopia
# 1                 composition_glass_percent                   Latvia
# 2                 composition_metal_percent                Australia
# 3                 composition_other_percent   Bosnia and Herzegovina
# 4       composition_paper_cardboard_percent         Macao SAR, China
# 5               composition_plastic_percent                    Palau
# 6    population_population_number_of_people                    China
# 7           special_waste_e_waste_tons_year                    China
# 8   special_waste_hazardous_waste_tons_year                  Ukraine
# 9   total_msw_total_msw_generated_tons_year                    China
# 10        waste_treatment_recycling_percent           Faeroe Islands
#
#    Waste recycling percent
# 0                   13.655
# 1                    21.23
# 2                     42.1
# 3                  0.00097
# 4                     20.0
# 5                   13.655
# 6                   13.655
# 7                   13.655
# 8                      3.2
# 9                   13.655
# 10                    67.0
